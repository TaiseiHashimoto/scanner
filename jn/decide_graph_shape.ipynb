# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 1, 0.01)
y = (np.tanh((x-0.93) * 5) + 1.0) * 0.5
plt.plot(x, y)

# %%
x = np.arange(0, 10, 0.1)
y = (np.tanh((x-1.0) * 1.0) + 1.0) * 0.3
plt.plot(x, y)

# %%
(np.tanh((0.5-1.0) * 1.0) + 1.0) * 0.3
# Out:
# 0.16136485282199706

# %%
x = np.arange(0, 1.0, 0.01)
y = (np.tanh((x - 0.99) * 15) + 1.0) * 0.7
plt.plot(x, y)

# %%
(np.tanh(0.01 * 15) + 1.0) * 0.7
# Out:
# 0.8042195235363226

# %%
x = np.arange(0, 1, 0.01)
y = np.tanh((x - 0.7) * 10) * 0.5 + 0.5
plt.plot(x, y)
plt.plot(x, x)

# %%
x = np.arange(0, 1, 0.01)
y = np.exp((x - 0.95) * 5)
plt.plot(x, y)

# %%
x = np.linspace(-2, 2, 20)
y = np.exp(x * 1.5)
plt.plot(x, y)

# %%
np.exp(-np.array([-0.51794417,  1.25873662,  0.59731479, -1.33810724]))
# Out:
# array([1.67857324, 0.28401262, 0.55028729, 3.81182181])

# %%
np.exp(np.array([1.21, 0.87]) * 3)
# Out:
# array([37.71281662, 13.59905085])
