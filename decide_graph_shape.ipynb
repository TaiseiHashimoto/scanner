# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 1, 0.01)
y = (np.tanh((x-0.95) * 10) + 1.0) * 0.5
plt.plot(x, y)

# %%
x = np.arange(0, 10, 0.1)
y = (np.tanh((x-2.0) * 0.5) + 1.0) * 0.5
plt.plot(x, y)

# %%
x = np.arange(0, 1, 0.01)
y = (np.tanh((x - 0.95) * 15) + 1.0) * 0.4
plt.plot(x, y)

# %%
y[x == 0.9]
# Out:
# array([0.18242552])
